# %% [markdown]
# # NumPy

# %%
import numpy as np

# %% [markdown]
#  Previously mitlab was used for the mathematical operation and then numpy come into the picture and then in python numpy library is used for mathematical operation

# %%
l = [1,2,3,4,5,6]

# %%
# coverting list into the array 
np.array(l)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr = np.array(l)

# %%
type(arr) # shows us that this is n dimesion array
# Out:
# numpy.ndarray

# %%
np.asarray(l) # it is also used to convert list into array
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a = (9,8,3,4,5,6,7)

# %%
type(a)
# Out:
# tuple

# %%
np.array(a) # we can convert the tuples into array too
# Out:
# array([9, 8, 3, 4, 5, 6, 7])

# %%
dict1 = {'A':[1,2,3] , 'B':[12,22,23] , 'C':[44,54,65]}

# %%
np.array(dict1)
# Out:
# array({'A': [1, 2, 3], 'B': [12, 22, 23], 'C': [44, 54, 65]}, dtype=object)

# %%
a = 'piyush'
np.array(a)
# Out:
# array('piyush', dtype='<U6')

# %%
# con convert any datatypes into the array easily

# %%
np.array([[1,2,3] , [4,5,6]]) # can convert two list into the array too
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr2 = np.array([[1,2,3] , [4,5,6]])

# %%
type(arr2)
# Out:
# numpy.ndarray

# %%
arr2.ndim

# and it will create a two dimension of array
# Out:
# 2

# %%
arr.ndim # so it is a 1 dimension array
# Out:
# 1

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.matrix(l) # if we pass the list or any datastructure in the matrix funcyion then by default the data structure will have minumumn two dimension
# Out:
# matrix([[1, 2, 3, 4, 5, 6]])

# %%
ls = np.matrix(l)

# %%
ls.ndim # the dimension of this array is 2 dimensional
# Out:
# 2

# %%
type(ls) # type is matrix
# Out:
# numpy.matrix

# %%
# another function 
l = [1,2,3,4,5,6]
np.asanyarray(l)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# let's pass a matrix here 
# it will not bring any type of change when we pass any matrix  
np.asanyarray(ls)
# Out:
# matrix([[1, 2, 3, 4, 5, 6]])

# %%
# array , asarray , asanyarray used for converting any datastructure into the n dimesnsional array

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
a = arr

# %%
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# let's make some changes in arr 
arr[0] = 34

# %%
arr
# Out:
# array([34,  2,  3,  4,  5,  6])

# %%
a # the changes we applied in the arr are also updating the array a
# Out:
# array([34,  2,  3,  4,  5,  6])

# %%
arr
# Out:
# array([34,  2,  3,  4,  5,  6])

# %%
a
# Out:
# array([34,  2,  3,  4,  5,  6])

# %%
# so this type of data coping operation is known as the solo copying operation 
# let's see the logic 
# e.g -->> we have an array arr which is stored in some kind of space 
# now we are saying a = arr so the a will always look at the space where the array is stored

# %%
b = np.copy(arr)

# %%
arr[0]
# Out:
# 34

# %%
arr[0] = 23

# %%
arr
# Out:
# array([23,  2,  3,  4,  5,  6])

# %%
b
# Out:
# array([34,  2,  3,  4,  5,  6])

# %%
# now it will not affect the arr or b

# %%
# and in the same way if we do any kind of changes in b it will not affect the arr

# %%
b[0] = 1234

# %%
b
# Out:
# array([1234,    2,    3,    4,    5,    6])

# %%
# in the upper function where arr = a , if we do any changes in the a then it will also update arr

# %%
a[0] = 35

# %%
a
# Out:
# array([35,  2,  3,  4,  5,  6])

# %%
arr
# Out:
# array([35,  2,  3,  4,  5,  6])

# %%
# in case of copy() method the arr dataset will be copied to another memory and the dataset will be assign to b

# %%
# so copy() method is known as deep copy

# %%
# in numpy we got different function in which we are able to find different different kind of arrays

# %%
np.fromfunction(lambda i , j : i ==j , (3,3)) # we give the shape as 3,3( 3 rows and 3 columns)
# fromfunction will take function as an argument and on the bases of data after applying function it will return array or matrix
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %%
# why it is returning us the above particular dataset

# %% [markdown]
# ![photo1688026922.jpeg](attachment:photo1688026922.jpeg)

# %%
np.fromfunction(lambda i , j: i *j , (3,3))  # going to perform same task but this time mul
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.]])

# %% [markdown]
# ![photo1688027200.jpeg](attachment:photo1688027200.jpeg)

# %%
list( i * i for i in range(5)) # it will generate some sort of data for us
# Out:
# [0, 1, 4, 9, 16]

# %%
# lets do the above task using the numpy

# %%
iterables = i* i for i in range(5)
# Out:
#   File "C:\Users\Asus\AppData\Local\Temp\ipykernel_18664\1113611707.py", line 1
#     iterables = i* i for i in range(5)
#                      ^
# SyntaxError: invalid syntax

# %%
# let's store the same things in the list or tuples 
iterables = (i * i for i in range(5))

# %%
iterables # if we pass it as a list then it will automatically show us the result
# Out:
# <generator object <genexpr> at 0x000001C9E3A87120>

# %%
list(iterables)
# Out:
# [0, 1, 4, 9, 16]

# %%
tuple(iterables)
# Out:
# ()

# %%
np.fromiter(iterables , float) # fromiter is a function which will take to arguments and one is dtype and generate an array.
# Out:
# array([], dtype=float64)

# %%
np.fromstring('23 45 56' , sep = ' ')
# here we give a command that from string generate an array and used sep as blank 
# so it will return us as array as result after spliting the string
# Out:
# array([23., 45., 56.])

# %%
np.fromstring('23 ,45 , 56' , sep = ',')
# Out:
# array([23., 45., 56.])

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# function that are used to get the information about the array 
arr2.ndim
# we can also get the information about dimension by looking at sq bracket 
# [] = 1 dimension , [[]] = 2 dimension
# Out:
# 2

# %%
arr2.size # will let us know about the total  no of element
# Out:
# 6

# %%
arr.size
# Out:
# 6

# %%
arr
# Out:
# array([35,  2,  3,  4,  5,  6])

# %%
arr2.shape # let us know the shape of array
# Out:
# (2, 3)

# %%
arr.shape # becoz it is a one dimension array
# Out:
# (6,)

# %%
arr
# Out:
# array([35,  2,  3,  4,  5,  6])

# %%
arr2.dtype
# Out:
# dtype('int32')

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
d = [11.11 , 22.22]

# %%
ak =np.array(d)

# %%
type(d)
# Out:
# list

# %%
ak.dtype
# Out:
# dtype('float64')
